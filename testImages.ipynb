# %%
import data_loader
import matplotlib.pyplot as plt

# %%
data = data_loader.DataLoader(dataset_name="test",
                                      img_res=(256, 256))
imgs_A, imgs_B = data.load_data(batch_size=3, is_testing=True)

# %%
imgs_B[0] = 0.5*imgs_B[0] + 0.5
fig, axs = plt.subplots(1, 1)
axs.imshow(imgs_B[0])
fig.savefig("images/test.png")
print(imgs_B[0].shape)
# Out:
# (256, 256, 3)

# %%
imgs_B.shape
# Out:
# (3, 256, 256, 3)

# %%
import pix2pix as CG

gan = CG.Pix2Pix()
gan.load(11)
